# %%
rent_df = pd.read_csv("G:/My Drive/Practical Data Engineering - 507/ADS 507 Project/Observed Rent Index by City.csv")

# %%
rent_df.columns[:10]
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'CountyName', '1/31/2015', '2/28/2015'],
#       dtype='object')

# %%
rent_df.shape
# Out:
# (3105, 128)

# %%
rent_df.isna().sum()[:15]
# Out:
# RegionID         0
# SizeRank         0
# RegionName       0
# RegionType       0
# StateName        0
# State            0
# Metro           13
# CountyName       0
# 1/31/2015     2477
# 2/28/2015     2470
# 3/31/2015     2453
# 4/30/2015     2446
# 5/31/2015     2440
# 6/30/2015     2440
# 7/31/2015     2436
# dtype: int64

# %%
rent_df.duplicated().value_counts()
# Out:
# False    3105
# Name: count, dtype: int64

# %%
rent_df[rent_df['Metro'].isna() == True]
# Out:
#       RegionID  SizeRank     RegionName RegionType StateName State Metro  \
# 1965     24303      2308      Dahlonega       city        GA    GA   NaN
# 2049     52776      2472    King George       city        VA    VA   NaN
# 2326     18482      3021    Harrodsburg       city        KY    KY   NaN
# 2429     45245      3299      Farmville       city        VA    VA   NaN
# 2452     52108      3359       Franklin       city        KY    KY   NaN
# 2557     17504      3707           Cody       city        WY    WY   NaN
# 2616     20280      3978    Ruther Glen       city        VA    VA   NaN
# 2626     56756      4032          Tomah       city        WI    WI   NaN
# 2665      4985      4249     Greensboro       city        GA    GA   NaN
# 2760     48984      4820          Havre       city        MT    MT   NaN
# 2856     20318      5472         Salida       city        CO    CO   NaN
# 2857    840373      5478       Catskill       city        NY    NY   NaN
# ...

# %%
rent_df[rent_df['CountyName'] == 'Greene County'][['Metro', 'RegionID', 'RegionName']]
# Out:
#                      Metro  RegionID   RegionName
# 125        Springfield, MO      7222  Springfield
# 1228  Dayton-Kettering, OH     10315  Beavercreek
# 1332  Dayton-Kettering, OH     16087        Xenia
# 1467  Dayton-Kettering, OH     24658     Fairborn
# 2220       Springfield, MO     33633     Republic
# 2665                   NaN      4985   Greensboro
# 2857                   NaN    840373     Catskill

# %%
rent_df[rent_df['RegionName'] == 'Greensboro']['Metro']
# Out:
# 69      Greensboro-High Point, NC
# 2665                          NaN
# Name: Metro, dtype: object
